# %%
# libraries

from datetime import datetime
import os
import re
import glob
import requests 
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Web Scapping

# %%
# web scrapping

link = 'https://www.mohfw.gov.in/'
req = requests.get(link)
soup = BeautifulSoup(req.content, "html.parser")

thead = soup.find_all('thead')[-1]
# print(thead)
head = thead.find_all('tr')

tbody = soup.find_all('tbody')[-1]
body = tbody.find_all('tr')

# print(rows)

head_rows = []
body_rows = []

for tr in head:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    head_rows.append(row)
    
for tr in body:
    td = tr.find_all(['th', 'td'])
    row = [i.text for i in td]
    body_rows.append(row)
    
# print(head_rows)
    
df_bs = pd.DataFrame(body_rows[:len(body_rows)-3], columns=head_rows[0])
    
df_bs.drop('S. No.', axis=1, inplace=True)
df_bs.head(36)
# Out:
#              Name of State / UT  \
# 0   Andaman and Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7                         Delhi
# 8                           Goa
# 9                       Gujarat
# 10                      Haryana
# 11             Himachal Pradesh
# 12            Jammu and Kashmir
# 13                    Jharkhand
# 14                    Karnataka
# 15                       Kerala
# 16                       Ladakh
# 17               Madhya Pradesh
# 18                  Maharashtra
# 19                      Manipur
# 20                    Meghalaya
# 21                      Mizoram
# 22                       Odisha
# 23                   Puducherry
# 24                       Punjab
# 25                    Rajasthan
# 26                   Tamil Nadu
# 27                    Telengana
# 28                      Tripura
# 29                  Uttarakhand
# 30                Uttar Pradesh
# 31                  West Bengal
# 32                       28380*
#
#    Total Confirmed cases (Including 111 foreign Nationals)   \
# 0                                                  33
# 1                                                1177
# 2                                                   1
# 3                                                  36
# 4                                                 277
# 5                                                  30
# 6                                                  37
# 7                                                2918
# 8                                                   7
# 9                                                3301
# 10                                                289
# 11                                                 40
# 12                                                523
# 13                                                 82
# 14                                                511
# 15                                                469
# 16                                                 20
# 17                                               2168
# 18                                               8068
# 19                                                  2
# 20                                                 12
# 21                                                  1
# 22                                                108
# 23                                                  8
# 24                                                313
# 25                                               2185
# 26                                               1885
# 27                                               1002
# 28                                                  2
# 29                                                 51
# 30                                               1955
# 31                                                649
# 32                                           \n6362\n
#
#    Cured/Discharged/Migrated Death
# 0                         11     0
# 1                        235    31
# 2                          1     0
# 3                         27     1
# 4                         56     2
# 5                         17     0
# 6                         32     0
# 7                        877    54
# 8                          7     0
# 9                        313   151
# 10                       176     3
# 11                        22     1
# 12                       137     6
# 13                        13     3
# 14                       188    20
# 15                       342     4
# 16                        14     0
# 17                       302   106
# 18                      1188   342
# 19                         2     0
# 20                         0     1
# 21                         0     0
# 22                        35     1
# 23                         3     0
# 24                        71    18
# 25                       518    41
# 26                      1020    24
# 27                       280    26
# 28                         2     0
# 29                        33     0
# 30                       335    31
# 31                       105    20
# 32                   \n886\n  None

# %% [markdown]
# # Cleaning data

# %%
# date-time information
# ---------------------

now  = datetime.now()
df_bs['Date'] = now.strftime("%m/%d/%Y") 
df_bs['Date'] = pd.to_datetime(df_bs['Date'], format='%m/%d/%Y')
df_bs['Name of State / UT'] = df_bs['Name of State / UT'].str.replace('#', '')
df_bs.head(36)
# Out:
#              Name of State / UT  \
# 0   Andaman and Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7                         Delhi
# 8                           Goa
# 9                       Gujarat
# 10                      Haryana
# 11             Himachal Pradesh
# 12            Jammu and Kashmir
# 13                    Jharkhand
# 14                    Karnataka
# 15                       Kerala
# 16                       Ladakh
# 17               Madhya Pradesh
# 18                  Maharashtra
# 19                      Manipur
# 20                    Meghalaya
# 21                      Mizoram
# 22                       Odisha
# 23                   Puducherry
# 24                       Punjab
# 25                    Rajasthan
# 26                   Tamil Nadu
# 27                    Telengana
# 28                      Tripura
# 29                  Uttarakhand
# 30                Uttar Pradesh
# 31                  West Bengal
# 32                       28380*
#
#    Total Confirmed cases (Including 111 foreign Nationals)   \
# 0                                                  33
# 1                                                1177
# 2                                                   1
# 3                                                  36
# 4                                                 277
# 5                                                  30
# 6                                                  37
# 7                                                2918
# 8                                                   7
# 9                                                3301
# 10                                                289
# 11                                                 40
# 12                                                523
# 13                                                 82
# 14                                                511
# 15                                                469
# 16                                                 20
# 17                                               2168
# 18                                               8068
# 19                                                  2
# 20                                                 12
# 21                                                  1
# 22                                                108
# 23                                                  8
# 24                                                313
# 25                                               2185
# 26                                               1885
# 27                                               1002
# 28                                                  2
# 29                                                 51
# 30                                               1955
# 31                                                649
# 32                                           \n6362\n
#
#    Cured/Discharged/Migrated Death       Date
# 0                         11     0 2020-04-27
# 1                        235    31 2020-04-27
# 2                          1     0 2020-04-27
# 3                         27     1 2020-04-27
# 4                         56     2 2020-04-27
# 5                         17     0 2020-04-27
# 6                         32     0 2020-04-27
# 7                        877    54 2020-04-27
# 8                          7     0 2020-04-27
# 9                        313   151 2020-04-27
# 10                       176     3 2020-04-27
# 11                        22     1 2020-04-27
# 12                       137     6 2020-04-27
# 30                       335    31 2020-04-27   26.8467    80.9462
# 31                       105    20 2020-04-27   22.9868    87.8550
# 32                   \n886\n  None 2020-04-27       NaN        NaN

# %%
df_bs.isna().sum()
# Out:
# Name of State / UT                                          0
# Total Confirmed cases (Including 111 foreign Nationals)     0
# Cured/Discharged/Migrated                                   0
# Death                                                       1
# Date                                                        0
# Latitude                                                    1
# Longitude                                                   1
# dtype: int64

# %% [markdown]
# # Saving data

# %%
# saving data
# -----------

file_name = now.strftime("covid_data")+'.csv'
file_loc = 'C:\\Users\\AAKASH SHARMA\\Desktop\\covid datasets\\'
df_bs.to_csv(file_loc + file_name, index=False)

df_bs.head(36)
# Out:
#              Name of State / UT  \
# 0   Andaman and Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7                         Delhi
# 8                           Goa
# 9                       Gujarat
# 10                      Haryana
# 11             Himachal Pradesh
# 12            Jammu and Kashmir
# 13                    Jharkhand
# 14                    Karnataka
# 15                       Kerala
# 16                       Ladakh
# 17               Madhya Pradesh
# 18                  Maharashtra
# 19                      Manipur
# 20                    Meghalaya
# 21                      Mizoram
# 22                       Odisha
# 23                   Puducherry
# 24                       Punjab
# 25                    Rajasthan
# 26                   Tamil Nadu
# 27                    Telengana
# 28                      Tripura
# 29                  Uttarakhand
# 30                Uttar Pradesh
# 31                  West Bengal
# 32                       28380*
#
#    Total Confirmed cases (Including 111 foreign Nationals)   \
# 0                                                  33
# 1                                                1177
# 2                                                   1
# 3                                                  36
# 4                                                 277
# 5                                                  30
# 6                                                  37
# 7                                                2918
# 8                                                   7
# 9                                                3301
# 10                                                289
# 11                                                 40
# 12                                                523
# 13                                                 82
# 14                                                511
# 15                                                469
# 16                                                 20
# 17                                               2168
# 18                                               8068
# 19                                                  2
# 20                                                 12
# 21                                                  1
# 22                                                108
# 23                                                  8
# 24                                                313
# 25                                               2185
# 26                                               1885
# 27                                               1002
# 28                                                  2
# 29                                                 51
# 30                                               1955
# 31                                                649
# 32                                           \n6362\n
#
#    Cured/Discharged/Migrated Death       Date  Latitude  Longitude
# 0                         11     0 2020-04-27   11.7401    92.6586
# 1                        235    31 2020-04-27   15.9129    79.7400
# 2                          1     0 2020-04-27   28.2180    94.7278
# 3                         27     1 2020-04-27   26.2006    92.9376
# 4                         56     2 2020-04-27   25.0961    85.3131
# 5                         17     0 2020-04-27   30.7333    76.7794
# 6                         32     0 2020-04-27   21.2787    81.8661
# 7                        877    54 2020-04-27   28.7041    77.1025
# 8                          7     0 2020-04-27   15.2993    74.1240
# 9                        313   151 2020-04-27   22.2587    71.1924
# 10                       176     3 2020-04-27   29.0588    76.0856
# 11                        22     1 2020-04-27   31.1048    77.1734
# 12                       137     6 2020-04-27   33.7782    76.5762
# 13                        13     3 2020-04-27   23.6102    85.2799
# 14                       188    20 2020-04-27   15.3173    75.7139
# 15                       342     4 2020-04-27   10.8505    76.2711
# 16                        14     0 2020-04-27   34.2996    78.2932
# 17                       302   106 2020-04-27   22.9734    78.6569
# 18                      1188   342 2020-04-27   19.7515    75.7139
# 19                         2     0 2020-04-27   24.6637    93.9063
# 20                         0     1 2020-04-27   25.4670    91.3662
# 21                         0     0 2020-04-27   23.1645    92.9376
# 22                        35     1 2020-04-27   20.9517    85.0985
# 23                         3     0 2020-04-27   11.9416    79.8083
# 24                        71    18 2020-04-27   31.1471    75.3412
# 25                       518    41 2020-04-27   27.0238    74.2179
# 26                      1020    24 2020-04-27   11.1271    78.6569
# 27                       280    26 2020-04-27   18.1124    79.0193
# 28                         2     0 2020-04-27   23.9408    91.9882
# 29                        33     0 2020-04-27   30.0668    79.0193
# 30                       335    31 2020-04-27   26.8467    80.9462
# 31                       105    20 2020-04-27   22.9868    87.8550
# 32                   \n886\n  None 2020-04-27       NaN        NaN

# %%
import pandas as pd
import folium

# %%
cmap=folium.Map(location=[20.5937,78.9629],zoom_start=5)

# %%
dataset = pd.read_csv("covid_data.csv")

# %%
dataset.head()
# Out:
#             Name of State / UT  \
# 0  Andaman and Nicobar Islands
# 1               Andhra Pradesh
# 2            Arunachal Pradesh
# 3                        Assam
# 4                        Bihar
#
#    Total Confirmed cases (Including 111 foreign Nationals)   \
# 0                                                 27
# 1                                                955
# 2                                                  1
# 3                                                 36
# 4                                                223
#
#    Cured/Discharged/Migrated  Death        Date  Latitude  Longitude
# 0                         11      0  2020-04-25   11.7401    92.6586
# 1                        145     29  2020-04-25   15.9129    79.7400
# 2                          1      0  2020-04-25   28.2180    94.7278
# 3                         19      1  2020-04-25   26.2006    92.9376
# 4                         46      2  2020-04-25   25.0961    85.3131

# %%
dataset.columns
# Out:
# Index(['Name of State / UT',
#        'Total Confirmed cases (Including 111 foreign Nationals) ',
#        'Cured/Discharged/Migrated', 'Death', 'Date', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
place = dataset[[ 'Latitude', 'Longitude']]

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
place = place.values.tolist()

# %%
place
# Out:
# [[11.7401, 92.6586],
#  [15.9129, 79.74],
#  [28.218000000000004, 94.7278],
#  [26.2006, 92.9376],
#  [25.0961, 85.3131],
#  [30.7333, 76.7794],
#  [21.2787, 81.8661],
#  [28.7041, 77.1025],
#  [15.2993, 74.124],
#  [22.2587, 71.1924],
#  [29.0588, 76.0856],
#  [31.1048, 77.1734],
#  [33.7782, 76.5762],
#  [23.6102, 85.2799],
#  [15.3173, 75.7139],
#  [10.8505, 76.2711],
#  [34.2996, 78.2932],
#  [22.9734, 78.6569],
#  [19.7515, 75.7139],
#  [24.6637, 93.9063],
#  [25.467, 91.3662],
#  [23.1645, 92.9376],
#  [20.9517, 85.0985],
#  [11.9416, 79.8083],
#  [31.1471, 75.3412],
#  [27.0238, 74.2179],
#  [11.1271, 78.6569],
#  [18.1124, 79.0193],
#  [23.9408, 91.9882],
#  [30.0668, 79.0193],
#  [26.8467, 80.9462],
#  [22.9868, 87.855]]

# %%
type(place)
# Out:
# list

# %%
def lw(i,color):
    folium.Marker(location=point,
    popup=str([dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i],dataset['Cured/Discharged/Migrated'][i],dataset['Death'][i]])[1:-1],
    icon=folium.Icon(color=color,icon='tint',icon_color="white")
                 ).add_to(cmap)

# %%
i=0
for point in place:
    if dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]<500:
        lw(i,'green')
    if dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]>500 and dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]<1000:
        lw(i,'orange')
    elif dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]>1000 and  dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]<3000:
        lw(i,'red')
    elif dataset['Total Confirmed cases (Including 111 foreign Nationals) '][i]>3000:
        lw(i,'darkred')
    i+=1

# %%
cmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
